# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)

# %%
df=pd.read_csv("../data/train_data.csv")
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (50000, 13)
#    customer_id  age  gender region  tenure_months  monthly_spend  \
# 0            1   43  Female  South             37          66.04
# 1            2   36    Male  North              9          93.26
# 2            3   45  Female   East             16          72.42
# 3            4   56    Male   West              4         106.27
# 4            5   35  Female   West              7          66.48
#
#    total_transactions  avg_session_time  support_ticket_count  \
# 0                  19             19.98                     2
# 1                  11             14.68                     0
# 2                  11             12.48                     1
# 3                  15             15.50                     2
# 4                  16             13.36                     4
#
#    last_login_days contract_type payment_method  churn
# 0                2       Monthly    Credit Card      0
# 1                0       Monthly    Credit Card      1
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customer_id           50000 non-null  int64
#  1   age                   50000 non-null  int64
#  2   gender                50000 non-null  str
#  3   region                50000 non-null  str
#  4   tenure_months         50000 non-null  int64
#  5   monthly_spend         50000 non-null  float64
#  6   total_transactions    50000 non-null  int64
#  7   avg_session_time      50000 non-null  float64
#  8   support_ticket_count  50000 non-null  int64
#  9   last_login_days       50000 non-null  int64
#  10  contract_type         50000 non-null  str
#  11  payment_method        50000 non-null  str
#  12  churn                 50000 non-null  int64
# dtypes: float64(2), int64(7), str(4)
# memory usage: 5.0 MB

# %%
df.describe()
# Out:
#         customer_id           age  tenure_months  monthly_spend  \
# count  50000.000000  50000.000000   50000.000000   50000.000000
# mean   25000.500000     37.762780      23.293980      70.072610
# std    14433.901067     11.452916      22.276238      24.782691
# min        1.000000     18.000000       1.000000      10.000000
# 25%    12500.750000     29.000000       7.000000      53.137500
# 50%    25000.500000     38.000000      16.000000      69.980000
# 75%    37500.250000     46.000000      33.000000      86.840000
# max    50000.000000     80.000000      96.000000     169.420000
#
#        total_transactions  avg_session_time  support_ticket_count  \
# count        50000.000000      50000.000000          50000.000000
# mean            19.976940         14.974383              2.006600
# std              4.465213          5.949993              1.414509
# min              4.000000          1.000000              0.000000
# ...

# %%
df.isnull().sum()
# Out:
# customer_id             0
# age                     0
# gender                  0
# region                  0
# tenure_months           0
# monthly_spend           0
# total_transactions      0
# avg_session_time        0
# support_ticket_count    0
# last_login_days         0
# contract_type           0
# payment_method          0
# churn                   0
# dtype: int64

# %%
df["churn"].value_counts(normalize=True)*100
# Out:
# churn
# 1    54.192
# 0    45.808
# Name: proportion, dtype: float64

# %%
df["churn"]
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 49995    1
# 49996    1
# 49997    0
# 49998    0
# 49999    1
# Name: churn, Length: 50000, dtype: int64

# %%
df["churn"].value_counts()
# Out:
# churn
# 1    27096
# 0    22904
# Name: count, dtype: int64

# %%
df["churn"].value_counts(normalize=True)
# Out:
# churn
# 1    0.54192
# 0    0.45808
# Name: proportion, dtype: float64

# %%
df.groupby("churn")["monthly_spend"].mean()
# Out:
# churn
# 0    69.175764
# 1    70.830705
# Name: monthly_spend, dtype: float64

# %%
df.groupby("churn")["support_ticket_count"].mean()
# Out:
# churn
# 0    1.973323
# 1    2.034728
# Name: support_ticket_count, dtype: float64

# %%
df.groupby("churn")["last_login_days"].mean()
# Out:
# churn
# 0    9.464155
# 1    9.553882
# Name: last_login_days, dtype: float64

# %%
df.groupby("churn")["tenure_months"].mean()
# Out:
# churn
# 0    24.122424
# 1    22.593704
# Name: tenure_months, dtype: float64

# %%
df.boxplot(column="tenure_months", by="churn")
plt.show()

# %%
df.boxplot(column="monthly_spend", by="churn")
plt.show()
